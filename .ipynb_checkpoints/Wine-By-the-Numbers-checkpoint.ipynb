# %% [markdown]
# # Wine - By the Numbers
#
# #### Note
# * Evaluate the quality of wines to determine if tester, region, or climate impacts the score and price of the wine.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests, gmaps, os, re, datetime

# Import API key
from api_keys import g_key

# %%
#Import the raw data file downloaded from https://www.kaggle.com/zynicide/wine-reviews
wine_file = "input/winemag-data-130k-v2.csv"
wine_df = pd.read_csv(wine_file)

#Print the header from the dataset
wine_df.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# 1                  NaN                NaN          Roger Voss
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
#
#   taster_twitter_handle                                              title  \
# 0          @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos
# 2      Pinot Gris            Rainstorm
# 3        Riesling           St. Julian
# 4      Pinot Noir         Sweet Cheeks

# %%
#This section is written to clean the data and set up the dataframe for analysis

#Drop the index coulmn that was part of the original dataset
wine_df = wine_df.drop(['Unnamed: 0'], axis=1)
#Drop the region_2 column as the data isn't required and provides little benefit to our analysis
wine_df = wine_df.drop(['region_2'], axis=1)
#Remove designation field as it isn't needed for our analysis and is missing a quarter of the values
wine_df = wine_df.drop(['designation'], axis=1)

#Remove data when the country or province data is blank
wine_df = wine_df.dropna(subset=['country', 'province'])

#Add a Column for the year of the wine
wine_df['Wine_Year'] = ""

#Print the header from the dataset
wine_df.head()
# Out:
#     country                                        description  points  price  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...      87    NaN
# 1  Portugal  This is ripe and fruity, a wine that is smooth...      87   15.0
# 2        US  Tart and snappy, the flavors of lime flesh and...      87   14.0
# 3        US  Pineapple rind, lemon pith and orange blossom ...      87   13.0
# 4        US  Much like the regular bottling from 2012, this...      87   65.0
#
#             province             region_1         taster_name  \
# 0  Sicily & Sardinia                 Etna       Kerin O’Keefe
# 1              Douro                  NaN          Roger Voss
# 2             Oregon    Willamette Valley        Paul Gregutt
# 3           Michigan  Lake Michigan Shore  Alexander Peartree
# 4             Oregon    Willamette Valley        Paul Gregutt
#
#   taster_twitter_handle                                              title  \
# 0          @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery Wine_Year
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos
# 2      Pinot Gris            Rainstorm
# 3        Riesling           St. Julian
# 4      Pinot Noir         Sweet Cheeks

# %%
# Read title string and populate with the year from the title string

for index, row in wine_df.iterrows():
    if index % 1000 == 0:
        print(f'Processing record number {index}')
                     
    title_parse = row['title']
    match = re.search('\d{4}', title_parse)
    Year = match.group(0) if match else '1900'
    
    if Year <= '1995' or Year >= '2020': 
        wine_df.loc[index, 'Wine_Year'] = 1900
    else:
        wine_df.loc[index, 'Wine_Year'] = Year

#Print the header from the dataset
wine_df.head()
# Out:
# Processing record number 0
# Processing record number 1000
# Processing record number 2000
# Processing record number 3000
# Processing record number 4000
# Processing record number 5000
# Processing record number 6000
# Processing record number 7000
# Processing record number 8000
# Processing record number 9000
# Processing record number 10000
# Processing record number 11000
# Processing record number 12000
# Processing record number 13000
# Processing record number 14000
# Processing record number 15000
# Processing record number 17000
# Processing record number 18000
# Processing record number 19000
# Processing record number 20000
# Processing record number 21000
# Processing record number 22000
# Processing record number 23000
# Processing record number 24000
# Processing record number 25000
# Processing record number 26000
# Processing record number 27000
# Processing record number 28000
# Processing record number 29000
# Processing record number 30000
# Processing record number 31000
# Processing record number 32000
# Processing record number 33000
# Processing record number 34000
# Processing record number 35000
# Processing record number 36000
# Processing record number 37000
# Processing record number 38000
# Processing record number 39000
# Processing record number 40000
# Processing record number 41000
# Processing record number 42000
# Processing record number 43000
# Processing record number 44000
# Processing record number 45000
# Processing record number 46000
# Processing record number 47000
# Processing record number 48000
# Processing record number 49000
# Processing record number 50000
# Processing record number 51000
# Processing record number 52000
# Processing record number 53000
# Processing record number 54000
# Processing record number 55000
# Processing record number 56000
# Processing record number 57000
# Processing record number 58000
# Processing record number 59000
# Processing record number 60000
# Processing record number 61000
# Processing record number 62000
# Processing record number 63000
# Processing record number 64000
# Processing record number 65000
# Processing record number 66000
# Processing record number 67000
# Processing record number 68000
# Processing record number 69000
# Processing record number 70000
# Processing record number 71000
# Processing record number 72000
# Processing record number 73000
# Processing record number 74000
# Processing record number 75000
# Processing record number 76000
# Processing record number 77000
# Processing record number 78000
# Processing record number 79000
# Processing record number 80000
# Processing record number 81000
# Processing record number 82000
# Processing record number 83000
# Processing record number 84000
# Processing record number 85000
# Processing record number 86000
# Processing record number 87000
# Processing record number 88000
# Processing record number 89000
# Processing record number 90000
# Processing record number 91000
# Processing record number 92000
# Processing record number 93000
# Processing record number 94000
# Processing record number 95000
# Processing record number 96000
# Processing record number 97000
# Processing record number 98000
# Processing record number 99000
# Processing record number 100000
# Processing record number 101000
# Processing record number 102000
# Processing record number 103000
# Processing record number 104000
# Processing record number 105000
# Processing record number 106000
# Processing record number 107000
# Processing record number 108000
# Processing record number 109000
# Processing record number 110000
# Processing record number 111000
# Processing record number 112000
# Processing record number 113000
# Processing record number 114000
# Processing record number 115000
# Processing record number 116000
# Processing record number 117000
# Processing record number 118000
# Processing record number 119000
# Processing record number 120000
# Processing record number 121000
# Processing record number 122000
# Processing record number 123000
# Processing record number 124000
# Processing record number 125000
# Processing record number 126000
# Processing record number 127000
# Processing record number 128000
# Processing record number 129000
#     country                                        description  points  price  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...      87    NaN
# 1  Portugal  This is ripe and fruity, a wine that is smooth...      87   15.0
# 2        US  Tart and snappy, the flavors of lime flesh and...      87   14.0
# 3        US  Pineapple rind, lemon pith and orange blossom ...      87   13.0
# 4        US  Much like the regular bottling from 2012, this...      87   65.0
#
#             province             region_1         taster_name  \
# 0  Sicily & Sardinia                 Etna       Kerin O’Keefe
# 1              Douro                  NaN          Roger Voss
# 2             Oregon    Willamette Valley        Paul Gregutt
# 3           Michigan  Lake Michigan Shore  Alexander Peartree
# 4             Oregon    Willamette Valley        Paul Gregutt
#
#   taster_twitter_handle                                              title  \
# 0          @kerinokeefe                  Nicosia 2013 Vulkà Bianco  (Etna)
# 1            @vossroger      Quinta dos Avidagos 2011 Avidagos Red (Douro)
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# 4           @paulgwine   Sweet Cheeks 2012 Vintner's Reserve Wild Child...
#
#           variety               winery Wine_Year
# 0     White Blend              Nicosia      2013
# 1  Portuguese Red  Quinta dos Avidagos      2011
# 2      Pinot Gris            Rainstorm      2013
# 3        Riesling           St. Julian      2013
# 4      Pinot Noir         Sweet Cheeks      2012

# %%
# Output File (CSV)
output_data_file = "Output/wine_cleaned.csv"
wine_df.to_csv(output_data_file, index=False, header=True)
